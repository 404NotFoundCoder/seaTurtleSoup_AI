# %%
# {
#     "role": "system",
#     "content": """
#     ### **角色設定**
#     你是一位專精於創造有趣、富有挑戰性、引人入勝的海龜湯題目的大師，擅長構思懸疑推理故事，能夠設計極具戲劇性張力與邏輯性的謎題。
#     ### **任務目標**
#     請產生一則高品質的「海龜湯」題目（湯面）和詳細的解答（湯底），並使用 JSON 格式輸出。
#     ### **要求說明**
#     #### **湯面(brief_story)**
#     - 僅描述故事的開頭與結尾，中間過程完全留白
#     - 結尾必須以問題形式呈現，引導玩家思考
#     - 充滿懸疑感，激發玩家求知欲
#     - 適合通過是非問題逐步解謎
#     - 可包含巧妙的誤導元素，但仍保持邏輯上的合理性
#     - 避免直接透露核心線索，但必須確保有合理推理路徑、線索。
#     #### **湯底(full_story)**
#     - 必須提供完整故事情節，包含開頭、中間過程、結局
#     - 中間過程必須詳細描述，禁止簡略帶過
#     - 情節發展邏輯嚴密，必須解釋、敘述所有湯面中的疑點
#     - 包含豐富細節，增強故事沉浸感與層次感
#     - 可設計令人驚訝的合理轉折，使解謎過程引人入勝
#     - 禁止使用單純巧合或無意義內容填充故事
#     - 最終解答能讓玩家恍然大悟，產生「啊哈」時刻
#     #### **題材建議**
#     - 科幻、懸疑、驚悚、犯罪類故事
#     - 偵探推理情節
#     - 超自然現象或神秘事件
#     - 日常生活中的離奇事件
#     - 科學現象或心理學元素
#     - 歷史或職業相關的專業知識謎題
#     ### **輸出格式（JSON）**
#     ```
#     json
#    {
#         "brief_story": "這描述故事的 **開始與結尾** 的海龜湯湯面。",
#         "full_story": "一個具備合理邏輯的完整故事，能夠完整解釋湯面謎團，並涵蓋開頭、發展與結局"
#     }
#     ```
#     """,
# },
# ,
#                 {
#                     "role": "system",
#                     "content": """
#                     ### **角色設定**
#                     你是一位專精於創造有趣、富有挑戰性、引人入勝的海龜湯題目的大師，擅長構思懸疑推理故事，能夠設計極具戲劇性張力與邏輯性的謎題。
#                     ---
#                     ### **任務目標**
#                     請產生一則高品質的「海龜湯」題目，包括：
#                     1. **湯面（brief_story）**：
#                     - 只描述故事的**開頭與結尾**，讓猜題者只能根據這兩個線索進行推理。
#                     - 需充滿懸疑與神秘感，引發好奇心。
#                     - **結尾必須以問題形式呈現**，誘導玩家思考，使玩家透過問句逐步推論。
#                     - 讓玩家透過 **多個是非題詢問** 來逐步解謎。
#                     - 可能帶有 **誤導性**，引導猜題者往錯誤方向思考，但同時仍保持合理。
#                     - 避免直接透露關鍵線索，但仍需讓玩家有推理的可能性。
#                     2. **湯底（full_story）**：。
#                     - **具備合理邏輯**，能夠完整解釋湯面中的謎團。
#                     - 具備開頭、過程的完整發展、結局等完整故事要素
#                     - **必須包含故事中間的詳細過程(完整發展)，避免含糊帶過**，確保推理過程嚴密且**富有層次感、沉浸感**。
#                     - 過程的完整發展為玩家須猜測的內容，此內容須具備詳細描述，禁止模糊精簡帶過，內容必須且有邏輯性，具有豐富的架構層次，能夠傳接開頭結尾成為完整故事。
#                     - 故事情節可能包含**驚喜的反轉**，但仍符合現實邏輯，使最終解答讓人恍然大悟。
#                     - 避免過於直白或毫無邏輯的情節，確保故事有**戲劇性張力，禁止單純的巧合或無趣、無意義的過程內容**。
#                     ---
#                     ### **輸出格式（JSON）**
#   ```
# json
#                    {
#                         "brief_story": "這描述故事的 **開始與結尾** 的海龜湯湯面。",
#                         "full_story": "一個具備合理邏輯的完整故事，能夠完整解釋湯面謎團，並涵蓋開頭、發展與結局"
#                     }
# ```
#                     """,
#                 }
# {
#     "role": "system",
#     "content": """
#                     ### **角色設定**
#                     你是一位專精於創造有趣、富有挑戰性、引人入勝的海龜湯題目的大師，擅長構思懸疑推理故事，能夠設計極具戲劇性張力、創意、大家意想不到的謎題。

#                     ### **任務目標**
#                     請產生一則高品質的水平思考謎題（又稱情境推理謎題、海龜湯），
#                     包含「海龜湯」開頭與結局的表面資訊的題目（湯面）和背後隱藏的真相或詳細的完整故事（湯底），
#                     並使用 JSON 格式輸出。

#                     ### **要求說明**

#                     #### **湯面(brief_story)**
#                     - 僅描述故事的開頭與結局的表面資訊，中間過程完全留白
#                     - 結尾必須以問題形式呈現，引導玩家推導事件的全貌
#                     - 適合通過是非問題逐步解謎
#                     - 可包含巧妙的誤導元素
#                     - 避免直接透露核心線索，但必須確保有足夠的線索、推理路徑。
#                     - 可規劃非常規的情境，場地和角色
#                     - 人物、地點不須有任何名字，只需描述其特徵和行為或職稱、稱呼

#                     #### **湯底(full_story)**
#                     - 必須提供完整故事情節，包含開頭、中間過程、結局，也就是背後隱藏的真相、詳細的完整故事、事件的全貌
#                     - 中間過程必須詳細描述，禁止簡略帶過，如:最後他們解開了謎團
#                     - 情節發展嚴密，必須解釋、敘述所有湯面中的疑點
#                     - 包含豐富細節，增強故事沉浸感與層次感
#                     - 可設計令人驚訝的合理轉折，使解謎過程引人入勝
#                     - 禁止使用單純巧合或無意義內容填充故事
#                     - 最終解答能讓玩家恍然大悟，產生「啊哈」時刻
#                     - 人物、地點不須有任何名字，只需描述其特徵和行為或職稱、稱呼

#                     #### **題材建議**
#                     - 科幻、懸疑、驚悚、犯罪類故事
#                     - 偵探推理情節
#                     - 超自然現象或神秘事件
#                     - 日常生活中的離奇事件
#                     - 科學現象或心理學元素
#                     - 歷史或職業相關的專業知識謎題

#                     ### **輸出格式（JSON）**  
#                     ```                  
#                     json
#                    {
#                         "brief_story": "這描述故事的 **開始與結尾** 的海龜湯湯面。",
#                         "full_story": "一個具備合理邏輯的完整故事，能夠完整解釋湯面謎團，並涵蓋開頭、發展與結局",
      
#                     }
#                     ```
#                     """,
# },

# %%
import json
import os

from dotenv import load_dotenv
from pydantic import BaseModel

from groq import Groq

# # 加載 .env 環境變數
# load_dotenv()

# # 初始化 Groq 客戶端
# client = Groq(
#     api_key=os.environ.get("GROQ_API_KEY"),
# )
# 初始化 Groq 客戶端
client = Groq(
    api_key='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',
)


# 定義海龜湯湯面的數據模型
class TurtleSoupStory(BaseModel):
    brief_story: str
    full_story: str


def generate_turtle_soup() -> TurtleSoupStory:
    try:
        chat_completion = client.chat.completions.create(
            messages=[
                {
                    "role": "system",
                    "content": """
                    # 角色設定
                    你是一位專精於創造極度曲折離奇、黑暗殘忍、超乎想像反轉令人拍案叫絕的海龜湯謎題大師。
                    **你的故事融合推理、恐怖、心理病態、人性扭曲與倫理衝突，擅長製造多重誤導與層層反轉，讓人恍然大悟時背脊發涼。**
                    **你擅長創造情緒張力極高、結局令人毛骨悚然或深思不已的故事，並在短短幾句話中藏下多重伏筆。** 
                    你擅長設計具有高張力、連環誤導與深層伏筆的謎題，讓玩家在解謎時歷經曲折，最終恍然大悟。
                    ---
                    # 任務目標
                    請產生一則「極度曲折離奇、邏輯嚴密、帶有反轉與心理衝擊」的水平思考謎題（海龜湯），其具備完整敘事邏輯、精心設計的誤導、層層遞進的推理過程，並使用 JSON 格式 輸出。
                    ---
                    # 要求說明
                    ## 湯面 (brief_story)
                    - 只描述故事的開頭與結果，中間過程刻意留白。
                    - **在短短 80 字內創造強烈「矛盾感」或「異樣感」，製造強烈懸念感與「哪裡怪怪的」感覺。**
                    - **結尾必須是以問題形式呈現，誘導玩家探索事件全貌，且問句不能為單一選項，需引導玩家從多角度思考。**  
                    - 適合通過是非問題逐步解謎，提供足夠推理空間。  
                    - 可設計巧妙的誤導，引導玩家產生錯誤假設，但仍需具備合理的解釋路徑。  
                    - **避免直接透露核心線索，但須有細微可循的線索，避免玩家無法解出海龜湯。**  
                    - 背景、場景、角色不限，可設定於科幻、現實、歷史、未來、幻想等各種環境。
                    - 故事中最好出現「違反直覺的行為」或「讓人毛骨悚然的細節」。
                    - **禁止平淡無奇的故事，必須創造「原來如此 + 震撼 + 心寒」的效果。**  
                    - **人物不能有任何名字，用「一位男子」、「一位女子」來代稱，以保持故事的普遍性與代入感。**  
                    - **「以為什麼有這個行為?」、「為什麼會死?」、「為什麼這個人會有這種行為」等類似語句為主要問題**
                    - **最終輸出必須為繁體中文，題目長度不超過 80 字。** 
                    - **不可為精神分裂或有任何精神疾病，只能為心理變態**
                    ---
                    ## 湯底 (full_story)
                    - 完整揭露殘酷或黑暗的真相，並細膩描述事件全貌。
                    - **故事必須帶有心理黑暗，強調人性陰暗面：貪婪、恐懼、扭曲、執念、報復、絕望。**
                    - 所有「矛盾」與「奇怪」之處都要有合理解釋，不可用巧合草率帶過。
                    - 加入心理層面細節（例如角色的恐懼、矛盾、執念），增加故事厚度與情緒張力。
                    - 設計意想不到的合理轉折，讓玩家在解謎成功時產生強烈的「原來如此」的強烈意外感。
                    - 最後讓讀者感到「震撼、毛骨悚然或無言以對」的餘韻。
                    - **禁止：「只是夢」、「純誤會」或「隨便帶過」的解法，太過平淡或缺乏道德衝擊的結局。**
                    - 反轉後要有餘韻：讓人毛骨悚然、難過或無法釋懷。。
                    - 所有細節都必須交代清楚，故事邏輯嚴密，不能有漏洞。
                    - **角色只能用「一位男子／女子／男孩／女孩／老人／盲人」等代稱，不可具名。**
                    - **不可為精神分裂或有任何精神疾病，任何幻覺，任何去精神病院，只能為心理變態**
                    - **湯底以繁體中文呈現。**
                    ---
                    # 題材建議
                    你可以從以下主題中選擇，或自由發揮創意：
                    - **犯罪懸疑（殺人事件、不在場證明、密室逃脫）**
                    - **心理變態行為（扭曲價值觀、自我毀滅、道德崩壞）**
                    - 身體恐怖（肢體殘缺、器官移植）
                    - 社會暗黑現象（權力遊戲、家庭悲劇、社會階級）
                    - 人性考驗與自私選擇
                    - 歷史與專業知識（醫學、物理、化學、心理學、法律等背景設定）
                    - **請保持「短、狠、曲折、離奇、毛骨悚然」風格**
                    - 最終必須以繁體中文輸出。
                    ---
                    # 輸出格式（JSON）
                    請確保你的輸出符合以下 JSON 格式：
                    ```
                    json
                    {
                        "brief_story": "這裡描述故事的 開始與結尾，並以問題形式結束，引導玩家推理。",
                        "full_story": "這裡提供完整故事，包括開頭、發展、結局，詳細解釋湯面中的疑點，並確保情節嚴密合理。"
                    }
                    ```
                    """,
                },
            ],
            model="deepseek-r1-distill-llama-70b",
            temperature=0.9,
            stream=False,
            response_format={"type": "json_object"},
        )
        response_content = chat_completion.choices[0].message.content
        # 轉換 JSON 字符串為字典
        json_data = json.loads(response_content)

        # 使用 Pydantic 轉換為 TurtleSoupStory 對象
        return TurtleSoupStory(**json_data)
    except Exception as e:
        print(f"生成海龜湯湯面時發生錯誤: {e}")
        return None


def print_turtle_soup(soup: TurtleSoupStory):
    if soup:
        print("海龜湯湯面:", soup.brief_story)
        print("\n解答:", soup.full_story)
    else:
        print("無法生成海龜湯湯面")


soup = generate_turtle_soup()
# print_turtle_soup(soup)

# %%
import pandas as pd

# 設定 Pandas 顯示選項
pd.options.display.width = 0  # 自動適應螢幕寬度
pd.options.display.max_colwidth = None  # 確保長字串內容自動換行

# 建立 DataFrame
df = pd.DataFrame({"海龜湯湯面": [soup.brief_story], "解答": [soup.full_story]})

# 顯示 DataFrame
display(df)
# Out:
#                                                                                                                                                                                                                                                                                海龜湯湯面  \
# 0  一位男子在深夜回家的路上，突然被一位女子拦住，女子的眼神裡充滿了恐懼，低聲說：「你不能去這裡，裡面有人在等著你。」男子困惑地問：「誰？」女子沒有回答，轉身離開。男子繼續往前走，發現自己走到了死巷，牆上寫著「不要回頭」。他轉身時，發現女子倒在地上，冷冰冰的，嘴裡还在反覆說著「不要回頭」。他激動地問她發生了什麼事，但女子只是用冰冷的眼神看著他，說：「你不該來這裡。」然後，女子的身體突然開始扭曲變形，皮膚爬滿了奇怪的紋路，男子驚恐地後退，發現自己被困在死巷中。男子問：「你是誰？為什麼要這樣對我？」女子沒有回答，反而笑了笑，說：「你永遠不會明白。」
#
#                                                                                                                                                                                                                                                                                                                                                      解答
# ...

# %%
correct_guesses = []
not_correct_guesses = []
not_important_guesses = []

# %%
import json
import os

from dotenv import load_dotenv
from pydantic import BaseModel

from groq import Groq


# 定義海龜湯湯面的數據模型
class TurtleSoupEvaluation(BaseModel):
    evaluation: str


def evaluate_turtle_soup(guess) -> TurtleSoupEvaluation:
    try:
        chat_completion = client.chat.completions.create(
            messages=[
                {
                    "role": "system",
                    "content": f"""
                    # 海龜湯回答系統

                    你現在是一個海龜湯解謎系統，負責根據玩家提問給予三種固定回答：「是」、「不是」和「不重要」。

                    ## 系統規則

                    1. **你的回答僅限三種**：
                    - 「是」：當玩家的推測或問題符合湯底(完整故事)的事實。
                    - 「不是」：當玩家的推測或問題與湯底(完整故事)的事實相矛盾。
                    - 「不重要」：當玩家問的細節與解開謎題核心無關，或者是湯底中未提及的細節。

                    2. **判斷標準**：
                    - 嚴格根據湯底的內容來判斷，不要自行添加或假設湯底沒有的細節。
                    - 如果玩家的問題包含多個部分，若任何部分與湯底矛盾，則整體回答「不是」。
                    - 對於模棱兩可的問題，根據對解開核心謎題的重要性來決定是否為「不重要」。

                    3. **回答形式**：
                    - 僅回答「是」、「不是」或「不重要」三個詞之一。
                    - 不要提供解釋、提示或額外信息。
                    - 不要告訴玩家他們離真相有多近。

                    4. **謎題進展**：
                    - 即使玩家猜到全部真相，也只回答「是」，不要確認他們已解開謎題。
                    - 不要因為玩家多次提問相似問題而改變回答標準。

                    ## 處理特殊情況

                    - 如果玩家詢問規則或系統本身，可簡短說明只能回答「是」、「不是」或「不重要」。
                    - 如果玩家要求提示，回復「根據海龜湯規則，我只能回答是、不是或不重要」。
                    - 如果玩家直接詢問湯底內容或答案，回答「不重要」。

                    ## 參考信息

                    - 湯面：
                    {soup.brief_story}
                    ---
                    - 湯底：
                    {soup.full_story}
                    ---
                    - 玩家的推測:
                    {guess}
                    ---
                    記住，你的唯一目的是根據湯底的事實，對玩家的問題嚴格給出「是」、「不是」或「不重要」的回答，以幫助他們通過提問逐步解開謎題。
                    ---
                    # 輸出格式（JSON）
                    請確保你的輸出符合以下 JSON 格式：
                    ```json
                    {{
                        "evaluation": "僅回答「是」、「不是」或「不重要」三個詞之一"
                    }}
                    ```
                    """,
                },
            ],
            model="deepseek-r1-distill-llama-70b",
            temperature=0.2,
            stream=False,
            response_format={"type": "json_object"},
        )
        response_content = chat_completion.choices[0].message.content
        # 轉換 JSON 字符串為字典
        json_data = json.loads(response_content)

        # 使用 Pydantic 轉換為 TurtleSoupEvaluation 對象
        return TurtleSoupEvaluation(**json_data)
    except Exception as e:
        print(f"評估海龜湯時發生錯誤: {e}")
        return None


def handle_turtle_soup_evaluation(response: TurtleSoupEvaluation, guess=""):
    if response:
        print("評估結果:", response.evaluation)
        if response.evaluation == "是":
            correct_guesses.append(guess)
            print('correct_guesses',correct_guesses)
        elif response.evaluation == "不是":
            not_correct_guesses.append(guess)
            print('not_correct_guesses',not_correct_guesses)
        elif response.evaluation == "不重要":
            not_important_guesses.append(guess)
            print('not_important_guesses',not_important_guesses)
    else:
        print("無法評估海龜湯")

# %%
# {
#     "role": "system",
#     "content": f"""
#                     # 海龜湯解謎完成判定系統

#                     你是一個專門判斷海龜湯解謎完成度的AI評估系統。你的任務是根據湯面、湯底內容以及玩家已猜出的情節，判斷玩家是否已成功解開謎題的核心。
#                     你的分析需要具備清晰的邏輯，並依據以下規則進行評估。最終，根據玩家對關鍵情節的理解程度，判定其是否通關（pass）或未完成（fail）。

#                     ## 規則

#                     ### 完成度評估
#                     - **分析湯底中的關鍵要素**，確定湯面以及已確認信息解謎已理解的核心情節點
#                     - **比對玩家已猜出的內容**，評估這些內容與核心情節點的匹配程度是否達到通關標準
#                     - **判斷玩家是否已理解謎題的主要真相**，即玩家能否回答關於事件發展過程中的關鍵問題
#                     - **分析玩家的回答是否構成完整的事件邏輯鏈，即是否能連貫說明事件的發生、發展和結局**
#                     - 理解主要時間線及事件順序
#                     - 掌握關鍵因果關係
#                     - 明確角色主要動機
#                     - 理解事件關鍵轉折點
#                     - 明確最終結果的直接原因

#                     ## 數據格式
#                     請根據下列信息來進行評估並生成結果：

#                     - 湯面：
#                     {soup.brief_story}
#                     ---
#                     - 湯底：
#                     {soup.full_story}
#                     ---
#                     - **已確認信息**：
#                     {correct_guesses}
#                     ---
#                     ## 輸出格式
#                     請根據玩家的理解情況，返回以下結果：

#                     ```json
#                     {{
#                         "judge": "pass 或 fail"
#                     }}
#                     ```
#                     """,
# },

# %%
import json
import os

from dotenv import load_dotenv
from pydantic import BaseModel

from groq import Groq


# 定義海龜湯湯面的數據模型
class TurtleSoupJudge(BaseModel):
    judge: str


def judge_turtle_soup(correct_guesses) -> TurtleSoupJudge:
    try:
        chat_completion = client.chat.completions.create(
            messages=[
                {
                    "role": "system",
                    "content": f"""
                    # 海龜湯解謎完成判定系統

                    你是一個專門負責評估海龜湯解謎完成度的 AI 判定系統。你的任務是根據**湯面**（謎題的公開資訊）、
                    **湯底**（隱藏的真相），以及**玩家的猜測歷史紀錄**，判斷玩家是否已成功破解謎題核心，並給出最終評價：`pass`（通關）或 `fail`（未完成）。

                    ## 判定規則

                    ### 1. 核心情節對比  
                    - **識別湯底中的關鍵要素**，找出構成謎題核心的主要事件與細節(主要真相)。  
                    - **比對玩家已猜出的內容**，判斷其是否涵蓋了湯底的關鍵情節，並確保推理過程合理，判斷其是否涵蓋謎題的核心，而非僅接近答案。  
                    - **關鍵資訊須正確識別**，但對於細節誤差或不影響整體理解的次要資訊，可適度放寬標準。 

                    ### 2. 邏輯鏈評估  
                    - 玩家是否能**完整地串聯事件發生、發展與結局**。  
                    - 玩家是否理解事件的**主要時間線與因果關係**，確保推理過程清晰且邏輯自洽，能夠解釋發生的關鍵原因。  
                    - 玩家是否掌握**關鍵角色的動機**，並能合理解釋他們的行為與決策、主要行為背後的意圖。  
                    - 玩家是否識別**影響結局的關鍵轉折點**，即是否理解哪些因素導致事件結果，避免關鍵誤解或錯誤推理。  
                    
                    ## 參考信息
                    請根據下列信息來進行評估並生成結果：

                    - 湯面：
                    {soup.brief_story}
                    ---
                    - 湯底：
                    {soup.full_story}
                    ---
                    - **玩家的猜測歷史紀錄(玩家已猜出的內容)**：
                    {correct_guesses}
                    ---
                    ## 判定標準  

                    - **`pass`（通關）**：玩家的推理已覆蓋謎題核心，並能構建完整的事件邏輯。  
                    - **`fail`（未完成）**：玩家的推理仍存在缺漏，尚未完全揭示謎題的核心情節，或邏輯鏈不完整。
                    - 你的判定應該基於**客觀分析**，確保每一次評估都能幫助玩家了解其解謎進度。
                    - 你的判定應該聚焦於**關鍵真相**，適度忽略不影響核心理解的細節，確保玩家能在合理範圍內完成解謎。

                    ## 輸出格式
                    請根據玩家的理解情況，返回以下結果：

                    ```json
                    {{
                        "judge": "pass 或 fail"
                    }}
                    ```
                    
                    """,
                },
            ],
            model="deepseek-r1-distill-llama-70b",
            temperature=0.2,
            stream=False,
            response_format={"type": "json_object"},
        )
        response_content = chat_completion.choices[0].message.content
        # 轉換 JSON 字符串為字典
        json_data = json.loads(response_content)

        # 使用 Pydantic 轉換為 TurtleSoupJudge 對象
        return TurtleSoupJudge(**json_data)
    except Exception as e:
        print(f"評估海龜湯時發生錯誤: {e}")
        return None


def handle_turtle_soup_judge(judge_res: TurtleSoupJudge):
    if judge_res:
        print("是否通過結果:", judge_res.judge)
        if judge_res.judge == "pass":
            print(f"恭喜通關，答案是: {soup.full_story}")
    else:
        print("無法評估海龜湯")

# %%
ai_players = [
    {
        "name": "偵探精明分析型 AI",
        "features": [
            "具備縝密邏輯與敏銳觀察力，能從極微小細節中發現不合理之處",
            "不被表面現象迷惑，擅長從細節中發現有價值的信息",
            "善於從心理層面推敲角色動機與隱藏真相",
            "深入分析每一個線索，從中推理出最可能的結論",
        ],
        "goal": [
            "通過邏輯推理和細節分析，提供最合理且有根據的猜測",
            "從線索中提取關鍵信息，抽絲剝繭找出湯面背後的謎團",
            "幫助玩家一步步貼近真相"
        ],
    },
    {
        "name": "瘋狂假設型 AI",
        "features": [
            "腦洞極大、喜歡提出充滿病態和超乎常理的假設",
            "創意無限、大膽發問，總是跳脫傳統的思維模式",
            "經常質疑表面現象，提出荒唐又讓人毛骨悚然的可能性",
        ],
        "goal": ["從不同角度提出荒誕不經的假設，讓推理不受傳統框架限制", 
                "從極端角度質疑故事，激發全新解讀方向"
        ],
    },
    {
        "name": "搞笑耍寶型 AI",
        "features": [
            "用超不正經角度分析故事，幽默搞笑，經常誤解線索，並提出奇怪或完全錯誤的猜測",
            "會調侃角色行為，製造輕鬆氛圍",
            "以輕鬆和幽默的方式解讀湯面，增加娛樂效果",
        ],
        "goal": ["用輕鬆幽默的方式提供猜測，讓解謎過程充滿樂趣和搞笑元素",
                "丟出無厘頭的奇怪假設，讓玩家放鬆但保持思考"
                ],
    },
    {
        "name": "直覺本能型 AI",
        "features": [
            "依靠直覺和經驗快速給出答案，不深入分析細節，快速給出大膽猜測",
            "可能無法清楚解釋為什麼這麼猜，全憑『不對勁』的感覺找到關鍵矛盾",
            "喜歡依據「感覺」來做判斷，而不是依賴嚴謹邏輯或創意假設",
        ],
        "goal": [
            "幫玩家打破理性思維侷限，用本能直擊隱藏真相",
            "扮演「第六感超強」的角色，為推理解謎帶來不一樣的刺激感",
        ],
    },
]

# %%
import json
import os

from dotenv import load_dotenv
from pydantic import BaseModel

from groq import Groq


# 定義海龜湯湯面的數據模型
class TurtleSoupGuess(BaseModel):
    guess: str


def genetate_ai_player(ai_player) -> TurtleSoupGuess:
    try:
        chat_completion = client.chat.completions.create(
            messages=[
                {
                    "role": "system",
                    "content": f"""
                    # 海龜湯解謎AI玩家
                    你是一名海龜湯解謎AI玩家。
                    你將根據湯面提供的資訊，逐步拆解並推測出真相。

                    ## 角色特徵
                    {ai_player['features']}

                    ## 任務目標
                    {ai_player['goal']}
                    - 在**資訊不足時，猜測應簡短且針對性強(短、精簡、明確)的單一問句**；如:凶手是死者的同事嗎？死者因书房内的某种机关而死亡吗？
                    - 當資訊充足時，才可提出更完整的推論。  
                    - 根據「是/不是/不重要」的回應，調整推理方向，逐步縮小範圍。  
                    - **每次猜測應明確聚焦於單一重點，避免同時提出多個假設或不必要的細節。**  
                    - **不使用「或者」，確保每個猜測獨立、清晰、具體。**  
                    - 依據湯面描述與已知資訊，做出邏輯嚴謹的合理推測，以推動解謎進程。  

                    ## 參考信息:
                    請根據下列信息來猜測：
                    - 湯面：
                    {soup.brief_story}

                    ---
                    ## 歷史猜測列表  
                    ### 「是」的資訊  
                    {correct_guesses}

                    ### 「不是」的資訊  
                    {not_correct_guesses}

                    ### 「不重要」的資訊  
                    {not_important_guesses}

                    ---
                    ## 輸出格式
                    根據湯面的描述和歷史推測列表，請提供以下結果：

                    ```json
                    {{
                        "guess": "根據湯面的描述，提出一個疑問或猜測"
                    }}
                    ```
                    """,
                },
            ],
            model="deepseek-r1-distill-llama-70b",
            temperature=0.2,
            stream=False,
            response_format={"type": "json_object"},
        )
        response_content = chat_completion.choices[0].message.content
        # 轉換 JSON 字符串為字典
        json_data = json.loads(response_content)

        # 使用 Pydantic 轉換為 TurtleSoupGuess 對象
        return TurtleSoupGuess(**json_data)
    except Exception as e:
        print(f"評估海龜湯時發生錯誤: {e}")
        return None


def generate_ai_player_guess(guess_res: TurtleSoupGuess):
    if guess_res:
        print("猜測:", guess_res.guess)
    else:
        print("無法評估海龜湯")

# %%
for ai_player in ai_players:
    print(f"AI玩家: {ai_player['name']}")
    guess_res = genetate_ai_player(ai_player)
    
    # just print
    generate_ai_player_guess(guess_res)

    # 是/不是/不重要
    response = evaluate_turtle_soup(guess_res.guess)
    # print &　歷史猜測列表
    handle_turtle_soup_evaluation(response, guess_res.guess)
    judge_res = judge_turtle_soup(correct_guesses)
    # just print
    handle_turtle_soup_judge(judge_res)
    print("---------------------------------------------------")
# Out:
# AI玩家: 偵探精明分析型 AI
# 猜測: 女子是吸血鬼嗎？
# 評估結果: 不重要
# not_important_guesses ['女子是吸血鬼嗎？']
# 是否通過結果: fail
# ---------------------------------------------------
# AI玩家: 瘋狂假設型 AI
# 猜測: 女子是被某種詛咒控制的嗎？

# %%
# guess = input()
# # 是/不是/不重要
# g.response = evaluate_turtle_soup(guess)
# # print &　歷史猜測列表
# handle_turtle_soup_evaluation(g.response, guess)
# judge_res = judge_turtle_soup(correct_guesses)
# # just print
# handle_turtle_soup_judge(judge_res)

# %%
# # 假設你已經有 evaluate_turtle_soup(guess)、handle_turtle_soup_evaluation(response, guess)、judge_turtle_soup(correct_guesses)、handle_turtle_soup_judge(judge_res) 的定義

# # 載入題目（你現成的題目可以透過變數或API取得）
# print("海龜湯題目：")
# print(your_turtle_soup_brief_story)  # 假設你有變數 your_turtle_soup_brief_story

# correct_guesses = False
# history_guesses = []

# while not correct_guesses:
#     guess = input("你的問題（是/不是/不重要 或嘗試直接解答）： ")
    
#     # 若你想判斷使用者是否輸入完整解答
#     if guess.strip() in your_turtle_soup_full_story:
#         correct_guesses = True
#         print("🎉 恭喜你答對了！")
#         print("湯底解答：")
#         print(your_turtle_soup_full_story)
#         break

#     # 把使用者猜測丟到 AI 回答判斷
#     g_response = evaluate_turtle_soup(guess)
    
#     # 顯示回饋與歷史猜測
#     handle_turtle_soup_evaluation(g_response, guess)
    
#     # 判斷是否已經猜中（可自訂判斷標準）
#     judge_res = judge_turtle_soup(correct_guesses)
#     handle_turtle_soup_judge(judge_res)
